# %%
import urllib
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Se descargan los archivos 
for x in range(0,501,50):
    print x
    if x<=50:
        urllib.urlretrieve("https://github.com/forero/ComputationalMethods/raw/master/homework/2015-01/hw3/Test/test00003.txt","test00003.txt")
        urllib.urlretrieve("https://github.com/forero/ComputationalMethods/raw/master/homework/2015-01/hw3/Test/test00050.txt","test00050.txt")
        
        
    elif x>50:
        urllib.urlretrieve("https://github.com/forero/ComputationalMethods/raw/master/homework/2015-01/hw3/Test/test00"+str(x)+".txt","test00"+str(x)+".txt")
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500

# %%
#Animación de las dos primeras columnas
columna1=[]
columna2=[]
for x in range(0,501,50):
    
    
    if x<=50:
        print x
        
        archivo=loadtxt('test00003.txt') 
        columna3=archivo[:,0]
        columna4=archivo[:,1]
        
        archivo2=loadtxt('test00050.txt') 
        columna5=archivo2[:,0]
        columna6=archivo2[:,1]
        columna1=numpy.concatenate((columna3,columna5),axis=0)
        columna2=numpy.concatenate((columna4,columna6),axis=0)
       
        
    elif x>50:
        print x
        archivo3=loadtxt('test00'+str(x)+'.txt') 
        columna1=columna1
        columna7=archivo3[:,0]
        columna8=archivo3[:,1]
        
        primeracolumna=numpy.concatenate((columna1,columna7),axis=0)#Arreglo que contienen la primera columna de todos los archivos
        segundacolumna=numpy.concatenate((columna2,columna8),axis=0)#Areglo que contiene la segunda columna de todos los archivos



#print primeracolumna
#print segundacolumna
   
plt.plot(primeracolumna, segundacolumna)
plt.show()
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
